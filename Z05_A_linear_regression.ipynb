# %% [markdown]
# # Regresja liniowa

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import sklearn.linear_model as lm
import matplotlib.pyplot as plt

# %% [markdown]
# Proszę narysować wykres dowolnej funkcji na odcinku $[0,3]$.
#
# Będzie to model, który będziemy chcieli znaleźć.

# %%
f = lambda x: ((x*2-1)*(x**2-2)*(x-2)+3)
x_tr = np.linspace(0, 3, 200)
y_tr = f(x_tr)
plt.figure(figsize=(6,6))
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr[:200], y_tr[:200], '--k')
plt.show()

# %% [markdown]
# Proszę wylosować kilka punktów z otoczenia funkcji $f(x)$.
#
# Na ich podstawie będziemy wykonywać naszej presykcji.

# %%
x = stats.uniform(0,3).rvs(100)
y = f(x) + stats.norm(0,0.2).rvs(len(x))
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_tr, y_tr, '--k');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# Nauczmy prosty model regresji liniowej
#
# $$
# y=a\cdot x + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.
# My narazie urzyjemy metody opartej na rozwiązaniu układu równań liniowych.

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p1 = np.linalg.lstsq(M1, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

# %% [markdown]
# Definiujemy naszą funkcję regresji

# %%
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0]

# %%
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

f_lr_2 = lambda x: p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

f_lr_2 = lambda x: p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Nauczmy prosty model regresji
#
# $$
# y=a_1\cdot x + a_2 \cdot x^2 + a_3 \cdot x ^3 + a_4 \cdot x ^4 + a_5 \cdot x^5 + b
# $$
#
# na naszych danych.
#
# Oraz narysujmy prostą regresji.

# %%
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4,x**5) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)

f_lr_2 = lambda x: p2[0][5]*pow(x,5)+p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 

x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_2(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x_f_lr, y_f_lr, 'g');
plt.plot(x, y, 'ok', ms=10);
plt.show()

# %% [markdown]
# # Zadanie
# Narysuj wszystkie wyniki na jednym wykresie.
#
# ## Która z krzywych jest najleprza?

# %%
M1 = np.vstack( (np.ones_like(x), x) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_1 = lambda x: p1[0][1] * x +p1[0][0]
x_f_lr = np.linspace(0., 3, 200)
y_f_lr = f_lr_1(x_tr)
plt.figure(figsize=(6,6));
axes = plt.gca()
axes.set_xlim([0,3])
axes.set_ylim([0,8])
plt.plot(x, y, 'ok', ms=10);
plt.plot(x_f_lr, y_f_lr, 'c');




#####x^2
M2 = np.vstack( (np.ones_like(x), x, x**2) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'b');


####x^3
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'r');

#####x^4
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'b');


####x^5
M2 = np.vstack( (np.ones_like(x), x, x**2,x**3,x**4,x**5) ).T
p2 = np.linalg.lstsq(M2, y, rcond=None)
f_lr_2 = lambda x: p2[0][5]*pow(x,5)+p2[0][4]*pow(x,4) +p2[0][3]*pow(x,3) +p2[0][2]*pow(x,2) + p2[0][1] * x + p2[0][0] 
y_f_lr = f_lr_2(x_tr)
plt.plot(x_f_lr, y_f_lr, 'g');
plt.show()

# %% [markdown]
# # Zadanie
# Musimy mieć jakąś miarę oceny.

# %%
import statsmodels.api as sm
Res1 = sm.OLS(y, M1).fit()
Res2 = sm.OLS(y, M2).fit()

# %%
print(Res1.summary2())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2.summary2())
# Out:
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.504
# Dependent Variable: y                AIC:                633.6066
# Date:               2022-03-29 00:50 BIC:                638.8169
# No. Observations:   100              Log-Likelihood:     -314.80
# Df Model:           1                F-statistic:        101.7
# Df Residuals:       98               Prob (F-statistic): 7.97e-17
# R-squared:          0.509            Scale:              32.408
# -------------------------------------------------------------------
#            Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# -------------------------------------------------------------------
# const     -3.9893     1.1987   -3.3279   0.0012   -6.3681   -1.6104
# x1         6.8564     0.6800   10.0836   0.0000    5.5070    8.2057
# -----------------------------------------------------------------
# Omnibus:              13.089       Durbin-Watson:          1.896
# Prob(Omnibus):        0.001        Jarque-Bera (JB):       13.935
# Skew:                 0.860        Prob(JB):               0.001
# Kurtosis:             3.620        Condition No.:          5
# =================================================================
#
# .....................................
# .....................................
# .....................................
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.999
# Dependent Variable: y                AIC:                -5.7754
# Date:               2022-03-29 00:50 BIC:                9.8556
# No. Observations:   100              Log-Likelihood:     8.8877
# Df Model:           5                F-statistic:        2.480e+04
# Df Residuals:       94               Prob (F-statistic): 5.38e-145
# R-squared:          0.999            Scale:              0.052144
# --------------------------------------------------------------------
#             Coef.    Std.Err.      t      P>|t|     [0.025    0.975]
# --------------------------------------------------------------------
# const      -1.0249     0.1575   -6.5078   0.0000   -1.3376   -0.7122
# x1         10.0438     1.0812    9.2895   0.0000    7.8971   12.1906
# x2         -2.2982     2.1643   -1.0618   0.2910   -6.5955    1.9991
# x3         -4.6275     1.7876   -2.5887   0.0112   -8.1767   -1.0782
# x4          1.8351     0.6506    2.8207   0.0058    0.5433    3.1268
# x5          0.0246     0.0863    0.2856   0.7758   -0.1467    0.1960
# ------------------------------------------------------------------
# Omnibus:              0.156         Durbin-Watson:           2.100
# Prob(Omnibus):        0.925         Jarque-Bera (JB):        0.053
# Skew:                 -0.056        Prob(JB):                0.974
# Kurtosis:             2.995         Condition No.:           10537
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Zadanie
# Analogiczne wyniki możemy izusklać za pomocą prostego kodu.

# %%
import statsmodels.formula.api as smf
# Turn the data into a pandas DataFrame, so that we
# can address them in the formulas with their name
df = pd.DataFrame({'x':x, 'y':y})

# Fit the models, and show the results
Res1F = smf.ols('y~x', df).fit()
Res2F = smf.ols('y ~ x+I(x**2)', df).fit()

# %%
print(Res1F.summary())
print(".....................................")
print(".....................................")
print(".....................................")
print(Res2F.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     101.7
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):           7.97e-17
# Time:                        00:50:53   Log-Likelihood:                -314.80
# No. Observations:                 100   AIC:                             633.6
# Df Residuals:                      98   BIC:                             638.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.9893      1.199     -3.328      0.001      -6.368      -1.610
# x              6.8564      0.680     10.084      0.000       5.507       8.206
# ==============================================================================
# Omnibus:                       13.089   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               13.935
# Skew:                           0.860   Prob(JB):                     0.000942
# Kurtosis:                       3.620   Cond. No.                         4.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# .....................................
# .....................................
# .....................................
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.798
# Method:                 Least Squares   F-statistic:                     196.2
# Date:                Tue, 29 Mar 2022   Prob (F-statistic):           8.17e-35
# Time:                        00:50:53   Log-Likelihood:                -269.47
# No. Observations:                 100   AIC:                             544.9
# Df Residuals:                      97   BIC:                             552.8
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.3435      1.154      5.496      0.000       4.053       8.634
# x            -12.7969      1.699     -7.532      0.000     -16.169      -9.425
# I(x ** 2)      6.4861      0.542     11.965      0.000       5.410       7.562
# ==============================================================================
# Omnibus:                       15.662   Durbin-Watson:                   2.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                4.886
# Skew:                           0.186   Prob(JB):                       0.0869
# Kurtosis:                       1.983   Cond. No.                         25.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
